# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Data fields
#
# -id - Identificator of the row (no name column)
#
# -country - The country where the wine was made
#
# -description - A few sentences from a sommelier describing the wine's taste, smell, look, feel, etc.
#
# -designation - The vineyard within the winery where the grapes that made the wine are from
#
# -points - The number of points WineEnthusiast rated the wine on a scale of 1-100 (though they say they only post
#
# -reviews for wines that score >=80)
#
# -province - The province or state that the wine is from
#
# -region_1 - The wine growing area in a province or state (ie Napa)
#
# -region_2 - Sometimes there are more specific regions specified within a wine growing area (ie Rutherford inside the Napa Valley), but this value can sometimes be blank
#
# -taster_name - Name of the person who tasted and reviewed the wine
#
# -taster_twitter_handle - Twitter handle for the person who tasted and reviewed the wine
#
# -title - The title of the wine review, which often contains the vintage if you're interested in extracting that feature
#
# -variety - The type of grapes used to make the wine (ie Pinot Noir)
#
# -winery - The winery that made the wine

# %% [markdown]
# ## Price Dataframe

# %%
pricedf = pd.read_csv('wine_y_train.csv')
pricedf.head()
# Out:
#        id  price
# 0   59970   26.0
# 1  107540   25.0
# 2   45945   34.0
# 3   49511   45.0
# 4   12978   36.0

# %% [markdown]
# ## x_train

# %%
x_train = pd.read_csv('wine_x_train.csv')
x_train.head()
# Out:
#        id  country                                        description  \
# 0   59970    Italy  Violet, iris, red berry and spice scents take ...
# 1  107540   France  While there is a youthful stalky element to th...
# 2   45945  Germany  There are edges of of smoke and violet on this...
# 3   49511   Israel  A bouquet of blackberry and juniper sets the s...
# 4   12978       US  This has earthy aromas and sun-dried tomato fl...
#
#                                 designation  points      province  \
# 0                                       NaN      90       Tuscany
# 1                                 Tradition      88  Loire Valley
# 2  Hochheimer Kirchenstück Spätlese Trocken      90      Rheingau
# 3                            Secret Reserve      91  Judean Hills
# 4                               Pauli Ranch      84    California
#
#            region_1 region_2         taster_name taster_twitter_handle  \
# 0  Chianti Classico      NaN       Kerin O’Keefe          @kerinokeefe
# ...

# %% [markdown]
# ## x_test

# %%
x_test = pd.read_csv('wine_x_test.csv')
x_test.head()
# Out:
#        id      country                                        description  \
# 0   20273  New Zealand  Few wineries in Central Otago devote much time...
# 1  122374    Argentina  This SB delivers citrus peel, grass and other ...
# 2  120362    Argentina  While this boxed wine smells a touch weedy and...
# 3   98892     Bulgaria  This wine has aromas of black plum and black r...
# 4   33852      Austria  This is one of the great Rieslings from the Wa...
#
#            designation  points          province  region_1 region_2  \
# 0                  NaN      88     Central Otago       NaN      NaN
# 1          Ciclos Fume      86             Other  Cafayate      NaN
# 2                  NaN      84  Mendoza Province   Mendoza      NaN
# 3              Reserve      87   Thracian Valley       NaN      NaN
# 4  Ried Schütt Smaragd      95            Wachau       NaN      NaN
#
#          taster_name taster_twitter_handle  \
# 0     Joe Czerwinski                @JoeCz
# ...

# %% [markdown]
# ## Combined df

# %%
combined_df = pd.read_csv('wine_combined.csv')
combined_df.head()
# Out:
#        id  price  country                                        description  \
# 0   59970     26    Italy  Violet, iris, red berry and spice scents take ...
# 1  107540     25   France  While there is a youthful stalky element to th...
# 2   45945     34  Germany  There are edges of of smoke and violet on this...
# 3   49511     45   Israel  A bouquet of blackberry and juniper sets the s...
# 4   12978     36       US  This has earthy aromas and sun-dried tomato fl...
#
#                                 designation  points      province  \
# 0                                       NaN      90       Tuscany
# 1                                 Tradition      88  Loire Valley
# 2  Hochheimer Kirchenstück Spätlese Trocken      90      Rheingau
# 3                            Secret Reserve      91  Judean Hills
# 4                               Pauli Ranch      84    California
#
#            region_1 region_2         taster_name taster_twitter_handle  \
# ...

# %%
X = combined_df[["foam", "beer"]]
y = combined_df["time"].values.reshape(-1, 1)
print(X.shape, y.shape)
